# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !pip uninstall tensorflow --quiet
# Out:
# Proceed (y/n)? y

# %%
# !pip install tensorflow-gpu==1.14.0 --quiet
# Out:
#      |████████████████████████████████| 377.0MB 46kB/s
#      |████████████████████████████████| 3.2MB 42.4MB/s
#      |████████████████████████████████| 491kB 37.1MB/s

# %%
# !git clone https://github.com/tensorflow/models
# !apt-get -qq install protobuf-compiler python-pil python-lxml python-tk
# !pip install --user Cython  --quiet
# !pip install --user contextlib2 --quiet
# !pip install --user jupyter --quiet
# !pip install --user matplotlib --quiet
#Move to models/research folder
# %cd models/research

#Convert protobuf files to Python code using Protobuf compiler installed in previous step
# !protoc object_detection/protos/*.proto --python_out=.
#Change path to models/research and models/research/slim folders based on where you have cloned github repository above
# %set_env PYTHONPATH=$PYTHONPATH:/content/models/research:/content/models/research/slim
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 35, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 34636 (delta 12), reused 26 (delta 3), pack-reused 34601
# Receiving objects: 100% (34636/34636), 512.55 MiB | 15.76 MiB/s, done.
# Resolving deltas: 100% (22358/22358), done.
# Checking out files: 100% (2495/2495), done.
# Selecting previously unselected package python-bs4.
# (Reading database ... 144429 files and directories currently installed.)
# Preparing to unpack .../0-python-bs4_4.6.0-1_all.deb ...
# Unpacking python-bs4 (4.6.0-1) ...
# Selecting previously unselected package python-pkg-resources.
# Preparing to unpack .../1-python-pkg-resources_39.0.1-2_all.deb ...
# Unpacking python-pkg-resources (39.0.1-2) ...
# Selecting previously unselected package python-chardet.
# Preparing to unpack .../2-python-chardet_3.0.4-1_all.deb ...
# Unpacking python-chardet (3.0.4-1) ...
# ...

# %%
#To be run from models/research folder
  # !python object_detection/builders/model_builder_test.py
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
# !cp '/content/drive/My Drive/CapStone/generate_tfrecord.py' .

# %%
# !cp -av '/content/drive/My Drive/CapStone/google-landmarks-dataset/AllImages' .
# Out:
# '/content/drive/My Drive/CapStone/google-landmarks-dataset/AllImages/2866_a8e1490b5f8d37e2.jpg' -> './AllImages/2866_a8e1490b5f8d37e2.jpg'
# '/content/drive/My Drive/CapStone/google-landmarks-dataset/AllImages/2866_bfe21a3c041cdadb.jpg' -> './AllImages/2866_bfe21a3c041cdadb.jpg'
# '/content/drive/My Drive/CapStone/google-landmarks-dataset/AllImages/2866_52962355b23d97dd.jpg' -> './AllImages/2866_52962355b23d97dd.jpg'
# '/content/drive/My Drive/CapStone/google-landmarks-dataset/AllImages/2866_ec2654f15eb80b2a.jpg' -> './AllImages/2866_ec2654f15eb80b2a.jpg'
# '/content/drive/My Drive/CapStone/google-landmarks-dataset/AllImages/1894_1078a00bdf260dad.jpg' -> './AllImages/1894_1078a00bdf260dad.jpg'
# '/content/drive/My Drive/CapStone/google-landmarks-dataset/AllImages/1894_097e914fac5a1a02.jpg' -> './AllImages/1894_097e914fac5a1a02.jpg'
# '/content/drive/My Drive/CapStone/google-landmarks-dataset/AllImages/1894_0aadcd0bdaf17bbf.jpg' -> './AllImages/1894_0aadcd0bdaf17bbf.jpg'
# ...

# %%
import sys
sys.path.append('/content/models/research')

# %%
#generate tfrecord for training data
# !python ./generate_tfrecord.py --csv_input='/content/models/research/AllImages/train.csv'  --image_dir='/content/models/research/AllImages' --output_path='train.record'
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
#generate tfrecord for test data
# !python generate_tfrecord.py --csv_input='/content/models/research/AllImages/test.csv'  --image_dir='/content/models/research/AllImages' --output_path='test.record'
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
# !ls -l /content/models/research/train.record
# Out:
# -rw-r--r-- 1 root root 17435886 May 10 14:49 /content/models/research/train.record

# %%
# !ls -l /content/models/research/test.record
# Out:
# -rw-r--r-- 1 root root 4021012 May 10 14:50 /content/models/research/test.record

# %%
# !cp /content/models/research/train.record  '/content/drive/My Drive/CapStone/google-landmarks-dataset/TFRecrods/'

# %%
# !cp /content/models/research/test.record  '/content/drive/My Drive/CapStone/google-landmarks-dataset/TFRecrods/'
